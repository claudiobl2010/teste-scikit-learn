# %%
from sklearn.datasets import load_iris
iris = load_iris()

x = iris.data
y = iris.target

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
valores_performance = {}

k = 1

while k <= 25:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    previsoes = knn.predict(x_test)
    acertos = metrics.accuracy_score(y_test, previsoes)
    valores_performance[k] = round(acertos, 4)
    k += 1

print(valores_performance)
# Out:
# {1: 1.0, 2: 1.0, 3: 1.0, 4: 0.9737, 5: 0.9737, 6: 0.9737, 7: 0.9737, 8: 0.9737, 9: 1.0, 10: 0.9737, 11: 1.0, 12: 0.9737, 13: 1.0, 14: 0.9737, 15: 0.9737, 16: 0.9737, 17: 0.9737, 18: 0.9474, 19: 0.9737, 20: 0.9474, 21: 0.9737, 22: 0.9737, 23: 0.9737, 24: 0.9737, 25: 0.9737}

# %%
import matplotlib.pyplot as plt

plt.plot(valores_performance.keys(), valores_performance.values())
plt.xlabel('Valores de K')
plt.ylabel('Performance')
plt.show()
