# %%
from sklearn.datasets import load_iris
iris = load_iris()

x = iris.data
y = iris.target

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
valores_performance = {}

k = 1

while k <= 25:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    previsoes = knn.predict(x_test)
    acertos = metrics.accuracy_score(y_test, previsoes)
    valores_performance[k] = round(acertos, 4)
    k += 1

print(valores_performance)
# Out:
# {1: 0.9474, 2: 0.9211, 3: 0.9737, 4: 0.9474, 5: 0.9737, 6: 0.9211, 7: 0.9474, 8: 0.9211, 9: 0.9474, 10: 0.9211, 11: 0.9474, 12: 0.9474, 13: 0.9474, 14: 0.9211, 15: 0.9474, 16: 0.9211, 17: 0.9211, 18: 0.9211, 19: 0.9211, 20: 0.9211, 21: 0.9211, 22: 0.8684, 23: 0.8947, 24: 0.8947, 25: 0.8947}

# %%
import matplotlib.pyplot as plt

plt.plot(valores_performance.keys(), valores_performance.values())
plt.xlabel('Valores de K')
plt.ylabel('Performance')
plt.show()
