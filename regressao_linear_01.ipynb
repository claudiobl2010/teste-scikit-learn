# %%
import pandas as pd

publi = pd.read_csv('advertising.csv')

publi.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
x = publi[['TV', 'Radio', 'Newspaper']]
y = publi['Sales']

# %%
x.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
import seaborn as sns

sns.pairplot(publi, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', height=4, kind='reg')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30)

# %%
from sklearn.linear_model import LinearRegression
reglin = LinearRegression()
reglin.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(reglin.coef_)
list(zip(['TV', 'Radio', 'Newspaper'], reglin.coef_))
# Out:
# [0.05250337 0.10244794 0.00070595]
# [('TV', 0.052503370242270864),
#  ('Radio', 0.10244794491541842),
#  ('Newspaper', 0.0007059494293139568)]

# %%
y_prev = reglin.predict(x_test)
print(y_prev)
# Out:
# [ 9.39538953 10.0109871   6.4140708  20.55259269 15.25676741 17.0814611
#  17.1588189  12.25423718 20.18965715  8.5619963   6.68495155 12.25864117
#  13.79793396  9.81348847 14.76640391  9.43685929 11.06252733 16.52704321
#  18.06930417 22.82642941 24.35847655 21.17548011 16.51752397  8.03532042
#  20.86203323 16.8811978  21.59508771 19.21292496  9.18201561 11.40082944
#   9.79980399  9.93190557 20.29577093 20.40381673 12.40637252 15.02251256
#   9.89841205 19.18185677  8.83294105  7.36336881 19.34862874  7.24433928
#   7.40081515 17.05093522  8.23548181 17.04183733 18.7400735  11.60090214
#  18.00976133 12.36335367 20.66815113  9.5825207  21.60585143 17.72661475
#  20.90578418 14.02157903  9.10621965 16.29475273 10.45991751 13.02172867]

# %% [markdown]
# ### MAE (Mean absolute error)

# %%
from sklearn import metrics

print(metrics.mean_absolute_error(y_test, y_prev))
# Out:
# 1.4511398265519166

# %% [markdown]
# ### MSE (Mean squared error)

# %%
print(metrics.mean_squared_error(y_test, y_prev))
# Out:
# 3.719475806670966

# %% [markdown]
# ### RMSE (Root mean squared error)

# %%
import numpy as np
print(np.sqrt(metrics.mean_squared_error(y_test, y_prev)))
# Out:
# 1.9285942566208596
